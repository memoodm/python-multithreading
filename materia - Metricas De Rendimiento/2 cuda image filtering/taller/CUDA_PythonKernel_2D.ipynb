# %%
import cv2
import cupy as cp
from google.colab import files
import matplotlib.pyplot as plt
import numpy as np

# ====================================================================
# --- 1. Cargar Imagen (CPU) ---
# ====================================================================

""" Cada pixel de la imagen tendra los 3 colores RGB con rangos de valores [0.0 a 1.0] """

uploaded = files.upload()

img_name = list(uploaded.keys())[0]
img = cv2.imread(img_name)
img_cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_np = img_cv_rgb.astype(np.float32) / 255.0
H, W, C = img_np.shape
print(f"Imagen cargada como NumPy array. Forma (H, W, C): {H}x{W}x{C}")

plt.imshow(img_np)
plt.show()
# Out:
#      <input type="file" id="files-dd33df00-a9a5-4490-ac7b-779583b90776" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd33df00-a9a5-4490-ac7b-779583b90776">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import time

import numpy as np
from numba import cuda
from numba import config
config.CUDA_ENABLE_PYNVJITLINK = 1 # resuelve bug de versiones

# %%
# ====================================================================
# --- 2. Crear Kernel (GPU) ---
# ====================================================================

@cuda.jit
def grayscale_kernel_2D(img_color, img_gray):
    """
    Kernel 2D que mapea las coordenadas (i, j) directamente usando
    índices de bloque y de hilo en las dimensiones X e Y.
    i = fila (altura), j = columna (ancho)
    """
    # 1. Obtener las coordenadas 2D (i, j)
    # cuda.grid(2) devuelve (j, i) -> (column,row)
    j, i = cuda.grid(2)

    # Obtener las dimensiones de la imagen de salida (filas, columnas)
    rows, cols = img_gray.shape

    # 2. Chequeo de límites
    # Asegurarse de que las coordenadas estén dentro de los límites de la imagen
    if i < rows and j < cols:
        # 3. Acceder a los componentes de color de la imagen original
        R = img_color[i, j, 0]
        G = img_color[i, j, 1]
        B = img_color[i, j, 2]

        # 4. Cálculo de la intensidad de gris
        # Se mantienen los coeficientes estándar
        gray_value = 0.2989 * R + 0.5870 * G + 0.1140 * B

        # 5. Asignar el valor de gris al array de salida
        img_gray[i, j] = gray_value

# %%
# ====================================================================
# --- 3. Preparación de la Imagen (CPU) ---
# ====================================================================

# Obtener dimensiones
H, W, C = img_np.shape # H = Altura/Filas, W = Ancho/Columnas, C = Canales
print(f"Dimensiones de la imagen (H, W, C): {H}, {W}, {C}")

# Crear array de salida en la CPU (solo filas y columnas, 1 canal)
img_gray_cpu = np.zeros((H, W), dtype=np.float32)

# ====================================================================
# --- 4. Procesamiento Acelerado en la GPU (CUDA 2D) ---
# ====================================================================

# 4.1 Transferir arrays de la CPU a la GPU (Dispositivo)
d_img_color = cuda.to_device(img_np)
d_img_gray = cuda.to_device(img_gray_cpu)

# 4.2 Configurar el lanzamiento del kernel 2D (Grid y Block)

# a. Dimensiones del Bloque (ejemplo 16x16 = 256 hilos)
# CUDA usa (X, Y) donde X es Ancho/Columna y Y es Alto/Fila
THREADS_PER_BLOCK_2D = (16, 16)

# b. Dimensiones de la Rejilla (Grid)
# Para el eje X (Ancho/Columna W)
BLOCKS_PER_GRID_2D_X = (W + THREADS_PER_BLOCK_2D[0] - 1) // THREADS_PER_BLOCK_2D[0]
# Para el eje Y (Alto/Fila H)
BLOCKS_PER_GRID_2D_Y = (H + THREADS_PER_BLOCK_2D[1] - 1) // THREADS_PER_BLOCK_2D[1]

# La configuración de la rejilla es (X, Y)
BLOCKS_PER_GRID_2D = (BLOCKS_PER_GRID_2D_X, BLOCKS_PER_GRID_2D_Y)


print(f"\nLanzando kernel CUDA con configuración 2D:")
print(f"  Dimensiones de la imagen: {W} x {H}")
print(f"  Hilos por bloque (X, Y): {THREADS_PER_BLOCK_2D}")
print(f"  Bloques por rejilla (X, Y): {BLOCKS_PER_GRID_2D}")

# 4.3 Lanzamiento y Sincronización
start_gpu = time.time()

# Lanzamiento del kernel 2D: [BLOQUES (X, Y), HILOS (X, Y)]
grayscale_kernel_2D[BLOCKS_PER_GRID_2D, THREADS_PER_BLOCK_2D](d_img_color, d_img_gray)

# Esperar a que todos los hilos terminen
cuda.synchronize()
time_gpu = time.time() - start_gpu
print(f"Tiempo de ejecución en GPU: {time_gpu:.4f} segundos")

# 4.4 Mover el resultado de la GPU de vuelta a la CPU
img_gray_gpu_result = d_img_gray.copy_to_host()
# Out:
# Dimensiones de la imagen (H, W, C): 2715, 3840, 3
#
# Lanzando kernel CUDA con configuración 2D:
#   Dimensiones de la imagen: 3840 x 2715
#   Hilos por bloque (X, Y): (16, 16)
#   Bloques por rejilla (X, Y): (240, 170)
# Tiempo de ejecución en GPU: 1.5313 segundos

# %%
# ====================================================================
# --- 5. Visualización del Resultado ---
# ====================================================================

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
# img_np debe normalizarse si no está en el rango [0, 255]
plt.imshow(img_np / 255 if img_np.max() > 1 else img_np)
plt.title("Imagen Original")
plt.axis('off')

plt.subplot(1, 2, 2)
# El resultado es float32, usamos cmap='gray'
plt.imshow(img_gray_gpu_result, cmap='gray')
plt.title("Imagen en Blanco y Negro (CUDA 2D)")
plt.axis('off')

plt.show()
